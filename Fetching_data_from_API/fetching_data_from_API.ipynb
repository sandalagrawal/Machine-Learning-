# %%
import pandas as pd

# %%
import requests

# %% [markdown]
# this url and headers code was directly available on tmdb api

# %%
url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI4NTZhN2JiNDJiMWNjOTdmZTQ5YTU4MjJmMmFkZWJjMiIsInN1YiI6IjY0ODcwMWJkOTkyNTljMDBjNWI1YWQyNSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.2FE4lLf_KhSufPwphYkMVk0wQVurusGL8FIhB4JVnBY"
}

# we stored the json in response variable
response = requests.get(url, headers=headers)

# %%
# to explicitly convert incoming data to JSON format
# ['results'] - because we only want the results list
response.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/nGxUxi3PfXDRm7Vg95VBNgNM8yc.jpg',
#   'genre_ids': [28, 12, 16, 878],
#   'id': 569094,
#   'original_language': 'en',
#   'original_title': 'Spider-Man: Across the Spider-Verse',
#   'overview': 'After reuniting with Gwen Stacy, Brooklyn’s full-time, friendly neighborhood Spider-Man is catapulted across the Multiverse, where he encounters the Spider Society, a team of Spider-People charged with protecting the Multiverse’s very existence. But when the heroes clash on how to handle a new threat, Miles finds himself pitted against the other Spiders and must set out on his own to save those he loves most.',
#   'popularity': 3309.344,
#   'poster_path': '/8Vt6mWEReuy4Of61Lnj5Xj704m8.jpg',
#   'release_date': '2023-05-31',
#   'title': 'Spider-Man: Across the Spider-Verse',
#   'video': False,
#   'vote_average': 8.8,
#   'vote_count': 1103},
#  {'adult': False,
#   'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg',
#   'genre_ids': [18, 80],
# ...

# %%
# to convert the above response into a dataframe

df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
df
# Out:
#         id                                          title  \
# 0   569094            Spider-Man: Across the Spider-Verse
# 1      238                                  The Godfather
# 2      278                       The Shawshank Redemption
# 3      240                          The Godfather Part II
# 4    19404                    Dilwale Dulhania Le Jayenge
# 5      424                               Schindler's List
# 6      129                                  Spirited Away
# 7      389                                   12 Angry Men
# 8   372058                                     Your Name.
# 9   496243                                       Parasite
# 10     497                                 The Green Mile
# 11     155                                The Dark Knight
# 12  772071                               Cuando Sea Joven
# 13     680                                   Pulp Fiction
# 14      13                                   Forrest Gump
# ...

# %%
# ab ye data bs 1 page ka tha. now we will loop this for all the pages present ( pages data we will get from JSON viewer)

# create an empty dataframe

df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
headers = {
      "accept": "application/json",
      "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI4NTZhN2JiNDJiMWNjOTdmZTQ5YTU4MjJmMmFkZWJjMiIsInN1YiI6IjY0ODcwMWJkOTkyNTljMDBjNWI1YWQyNSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.2FE4lLf_KhSufPwphYkMVk0wQVurusGL8FIhB4JVnBY"
  }
for i in range(1, 500):

  url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page={}".format(i)
  response = requests.get(url, headers=headers)
  temp_df = pd.DataFrame(response.json()['results'], columns = ['id','title','overview','release_date','popularity','vote_average','vote_count'])
  df = pd.concat([df, temp_df], ignore_index = True)

# %% [markdown]
# executed the above for loop till 500 page because of some error in later pages! worked!!

# %%
df
# Out:
#            id                                      title  \
# 0      569094        Spider-Man: Across the Spider-Verse
# 1         238                              The Godfather
# 2         278                   The Shawshank Redemption
# 3         240                      The Godfather Part II
# 4       19404                Dilwale Dulhania Le Jayenge
# ...       ...                                        ...
# 39975    1979  Fantastic Four: Rise of the Silver Surfer
# 39976  174316                              A Case of You
# 39977   57431                                 The Sitter
# 39978   49849                           Cowboys & Aliens
# 39979   10200              The Day the Earth Stood Still
#
#                                                 overview release_date  \
# 0      After reuniting with Gwen Stacy, Brooklyn’s fu...   2023-05-31
# 1      Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# ...

# %%
df.shape
# Out:
# (39980, 7)

# %%
# to convert this dataframe to csv file
df.to_csv('movies.csv')
